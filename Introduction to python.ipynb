# %% [markdown]
# INTRODUCTION TO PYTHON:

# %% [markdown]
# PYTHON LIST:

# %%
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]

# %%
areas[9]=10.50

# %%
areas[4]="chill zone"

# %%
print(areas)
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'chill zone', 20.0, 'bedroom', 10.75, 'bathroom', 10.5]

# %%
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50

# %%
house = [["hallway", hall],
         ["kitchen", kit],
         ["living room", liv],
         ["bedroom", bed],
         ["bathroom", bath]]

# %%
print(house)
# Out:
# [['hallway', 11.25], ['kitchen', 18.0], ['living room', 20.0], ['bedroom', 10.75], ['bathroom', 9.5]]

# %%
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]

# %%
print(areas[1])
# Out:
# 11.25

# %%
print(areas[-1])
# Out:
# 9.5

# %%
print(areas[5])
# Out:
# 20.0

# %%
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]

# %%
downstairs = areas[0:6]

# %%
upstairs = areas[6:]

# %%
print(downstairs)
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'living room', 20.0]

# %%
print(upstairs)
# Out:
# ['bedroom', 10.75, 'bathroom', 9.5]

# %%
house = [["hallway", 11.25],
         ["kitchen", 18.0],
         ["living room", 20.0],
         ["bedroom", 10.75],
         ["bathroom", 9.50]]

# %%
house[-1][1]
# Out:
# 9.5

# %%
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]

# %%
areas[9]=10.50

# %%
areas[4]="chill zone"

# %%
print(areas)
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'chill zone', 20.0, 'bedroom', 10.75, 'bathroom', 10.5]

# %%
areas = ["hallway", 11.25, "kitchen", 18.0, "chill zone", 20.0,
         "bedroom", 10.75, "bathroom", 10.50]

# %%
areas_1 = areas+["poolhouse",24.5]

# %%
areas_2 = areas_1+["garage",15.45]

# %%
print(areas_1)
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'chill zone', 20.0, 'bedroom', 10.75, 'bathroom', 10.5, 'poolhouse', 24.5]

# %%
print(areas_2)
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'chill zone', 20.0, 'bedroom', 10.75, 'bathroom', 10.5, 'poolhouse', 24.5, 'garage', 15.45]

# %%
areas = ["hallway", 11.25, "kitchen", 18.0,
        "chill zone", 20.0, "bedroom", 10.75,
         "bathroom", 10.50, "poolhouse", 24.5,
         "garage", 15.45]

# %%
del areas[10]

# %%
print(areas)
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'chill zone', 20.0, 'bedroom', 10.75, 'bathroom', 10.5, 24.5, 'garage', 15.45]

# %%
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# %%
areas_copy = list(areas)

# %%
areas_copy[0] = 5.0

# %%
print(areas)
# Out:
# [11.25, 18.0, 20.0, 10.75, 9.5]

# %% [markdown]
# FUNCTIONS:

# %%
var1 = [1, 2, 3, 4]
var2 = True

# %%
print(type(var1))
# Out:
# <class 'list'>

# %%
print(len(var1))
# Out:
# 4

# %%
out2 = int(var2)

# %%
print(out2)
# Out:
# 1

# %%
first = [11.25, 18.0, 20.0]
second = [10.75, 9.50]

# %%
full = first + second

# %%
full_sorted = sorted(full, reverse=True)

# %%
print(full_sorted)
# Out:
# [20.0, 18.0, 11.25, 10.75, 9.5]

# %% [markdown]
# METHODS:

# %%
place = "poolhouse"

# %%
place_up = place.upper()

# %%
print(place)
print(place_up)
# Out:
# poolhouse
# POOLHOUSE

# %%
print("place:",place.count("o"))
# Out:
# place: 3

# %%
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# %%
print(areas.index(20.0))
# Out:
# 2

# %%
print(areas.count(9.50))
# Out:
# 1

# %%
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# %%
areas.append(24.5)
areas.append(15.45)

# %%
print(areas)
# Out:
# [11.25, 18.0, 20.0, 10.75, 9.5, 24.5, 15.45]

# %%
areas.reverse()

# %%
print(areas)
# Out:
# [15.45, 24.5, 9.5, 10.75, 20.0, 18.0, 11.25]

# %% [markdown]
# PACKAGES:

# %%
import math
C = 2 * 0.43 * math.pi

# %%
A = math.pi * 0.43 ** 2

# %%
print("Circumference: " + str(C))
print("Area: " + str(A))
# Out:
# Circumference: 2.701769682087222
# Area: 0.5808804816487527

# %%
from math import pi
C = 2 * 0.43 * pi
A = pi * 0.43 ** 2

# %%
print("Circumference: " + str(C))
print("Area: " + str(A))
# Out:
# Circumference: 2.701769682087222
# Area: 0.5808804816487527

# %% [markdown]
# NUMPY:

# %%
import numpy as np
baseball = [180, 215, 210, 210, 188, 176, 209, 200]

# %%
np_baseball=np.array(baseball)

# %%
print(type(np_baseball))
# Out:
# <class 'numpy.ndarray'>

# %%
import numpy as np

height_in = [74, 74, 72, 75, 75, 73]
weight_lb = [180, 215, 210, 188, 176, 209]

# %%
np_height_in = np.array(height_in)
np_weight_lb = np.array(weight_lb)

# %%
print(np_height_in[100:111])
# Out:
# []

# %% [markdown]
# 2D NUMPY ARRAYS:

# %%
import numpy as np

# %%
baseball = [[180, 78.4],
            [215, 102.7],
            [210, 98.5],
            [188, 75.2]]

# %%
np_baseball=np.array(baseball)

# %%
print(type(np_baseball))
print(np_baseball.shape)
# Out:
# <class 'numpy.ndarray'>
# (4, 2)

# %%
import numpy as np

# %%
np_baseball = np.array(baseball)

# %%
print(np_baseball.shape)
# Out:
# (4, 2)

# %%
import numpy as np

# %%
baseball = [
    [74, 180],
    [74, 215],
    [72, 210],
    [75, 188],
    [75, 176],
    [73, 209]
]

# %%
np_baseball = np.array(baseball)

# %%
updated = np_baseball + 10
print("Addition of np_baseball and 10:\n", updated)
# Out:
# Addition of np_baseball and 10:
#  [[ 84 190]
#  [ 84 225]
#  [ 82 220]
#  [ 85 198]
#  [ 85 186]
#  [ 83 219]]

# %%
conversion = np.array([2.54, 0.453592])

# %%
np_baseball_metric = np_baseball * conversion
print("np_baseball converted to metric units:\n", np_baseball_metric)
# Out:
# np_baseball converted to metric units:
#  [[187.96      81.64656 ]
#  [187.96      97.52228 ]
#  [182.88      95.25432 ]
#  [190.5       85.275296]
#  [190.5       79.832192]
#  [185.42      94.800728]]

# %%
conversion = np.array([2.54, 0.453592])
print("np_baseball * conversion:\n", np_baseball * conversion)
# Out:
# np_baseball * conversion:
#  [[187.96      81.64656 ]
#  [187.96      97.52228 ]
#  [182.88      95.25432 ]
#  [190.5       85.275296]
#  [190.5       79.832192]
#  [185.42      94.800728]]

# %%
import numpy as np

# %%
np_baseball = np.array(baseball)

# %%
print(np_baseball + updated)
# Out:
# [[158 370]
#  [158 440]
#  [154 430]
#  [160 386]
#  [160 362]
#  [156 428]]

# %%
conversion = np.array([0.0254, 0.453592, 1])

# %% [markdown]
# NUMPY BASIC STATISTICS:

# %%
import numpy as np

# %%
np_height_in=np.array(np_baseball[:,0])

# %%
print(np.mean(np_height_in))
# Out:
# 73.83333333333333

# %%
print(np.median(np_height_in))
# Out:
# 74.0

# %%
avg = np.mean(np_baseball[:,0])
print("Average: " + str(avg))
# Out:
# Average: 73.83333333333333

# %%
med =np.median(np_baseball[:,0])
print("Median: " + str(med))
# Out:
# Median: 74.0

# %%
stddev = np.std(np_baseball[:,0])
print("Standard Deviation: " + str(stddev))
# Out:
# Standard Deviation: 1.0671873729054748

# %%
corr = np.corrcoef(np_baseball[:,0],np_baseball[:,1])
print("Correlation: " + str(corr))
# Out:
# Correlation: [[ 1.         -0.69094846]
#  [-0.69094846  1.        ]]
